# %% [markdown]
# **PAUSED / NOT AUTHORIZED:** Do not use **Run all**.
#
# # Semantic-texture soft-route mechanism validation untouched confirmation
#
# This entrypoint remains paused until the returned selection artifact and SHA256SUMS pass read-only authentication. It requires exact `CEG_WM_SOFT_ROUTE_MECHANISM_VALIDATION_REVISION` and `CEG_WM_SOFT_ROUTE_MECHANISM_VALIDATION_SELECTION_ARTIFACT_SHA256` values; it never scans latest or refits provisional calibration.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import userdata
import pathlib, re, subprocess, zipfile
revision = userdata.get('CEG_WM_SOFT_ROUTE_MECHANISM_VALIDATION_REVISION')
selection_sha256 = userdata.get('CEG_WM_SOFT_ROUTE_MECHANISM_VALIDATION_SELECTION_ARTIFACT_SHA256')
assert re.fullmatch(r'[0-9a-f]{40}', revision or '')
assert re.fullmatch(r'[0-9a-f]{64}', selection_sha256 or '')
subprocess.run(['git', 'clone', '--filter=blob:none', '--no-checkout', 'https://github.com/RICHAAARC/CEG-WM.git', '/content/CEG-WM'], check=True)
subprocess.run(['git', 'checkout', '--detach', revision], cwd='/content/CEG-WM', check=True)
package = pathlib.Path('/content/semantic_texture_soft_route_untouched_confirmation_package.zip')
subprocess.run(['python', '/content/CEG-WM/scripts/experiment_execution/build_semantic_texture_soft_route_mechanism_validation_package.py', '--repository-root', '/content/CEG-WM', '--source-revision', revision, '--output', str(package), '--split', 'untouched_confirmation'], check=True)
with zipfile.ZipFile(package) as archive: archive.extractall('/content/semantic_texture_soft_route_untouched_confirmation_package')

# %%
import os, uuid
root = pathlib.Path('/content/drive/MyDrive/CEG-WM')
run_id = 'semantic-texture-soft-route-untouched-confirmation-' + uuid.uuid4().hex
output = root / 'semantic_texture_soft_route_mechanism_validation/untouched_confirmation' / run_id
asset = root / 'semantic_texture_soft_detector_assets/f9dd6df410cb4f7895376c65c5f6d3e764f6cfddabd0d64d525fdaaefd93de3d/semantic_texture_soft_detector_asset_bundle.json'
subprocess.run(['python', '/content/semantic_texture_soft_route_untouched_confirmation_package/scripts/experiment_execution/semantic_texture_soft_route_untouched_confirmation_bootstrap.py', '--repository-root', '/content/semantic_texture_soft_route_untouched_confirmation_package', '--checkpoint', str(root / 'models/inspyrenet/ckpt_base.pth'), '--execution-root', '/content/semantic_texture_soft_route_untouched_confirmation_execution', '--entrypoint-args', '--execute', '--run-id', run_id, '--output-root', str(output), '--selection-artifact-root', str(root), '--selection-artifact-sha256', selection_sha256, '--detector-asset-bundle', str(asset)], check=True, env={**os.environ, 'HF_TOKEN': userdata.get('HF_TOKEN'), 'CEG_WM_ROOT_KEY': userdata.get('CEG_WM_ROOT_KEY')})
