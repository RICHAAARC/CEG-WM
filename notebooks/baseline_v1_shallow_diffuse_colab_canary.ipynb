# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Engineering-only launcher: no result or paper claim is made here.
import os, subprocess, pathlib
REPO='https://github.com/RICHAAARC/CEG-WM.git'; BRANCH='Baseline-V1'; RUN_ID='shallow_diffuse_sd35_one_unit_v1'
OFFICIAL='https://github.com/liwd190019/Shallow-Diffuse.git'; OFFICIAL_EXACT='c80c553fdf66fda8db735d77a9d56538b7a0ade8'
root=pathlib.Path('/content/cegwm'); subprocess.run(['git','clone',REPO,str(root)],check=True); resolved_exact=subprocess.run(['git','-C',str(root),'rev-parse',f'origin/{BRANCH}'],text=True,capture_output=True,check=True).stdout.strip(); subprocess.run(['git','-C',str(root),'checkout','--detach',resolved_exact],check=True)
official=pathlib.Path('/content/shallow_diffuse'); subprocess.run(['git','clone',OFFICIAL,str(official)],check=True); subprocess.run(['git','-C',str(official),'checkout','--detach',OFFICIAL_EXACT],check=True); official_head=subprocess.run(['git','-C',str(official),'rev-parse','HEAD'],text=True,capture_output=True,check=True).stdout.strip(); official_dirty=subprocess.run(['git','-C',str(official),'status','--porcelain'],text=True,capture_output=True,check=True).stdout.strip(); assert official_head==OFFICIAL_EXACT and not official_dirty
assert os.environ.get('HF_TOKEN'), 'HF_TOKEN must be environment-only'; run_dir=pathlib.Path('/content/drive/MyDrive/CEG-WM/Baseline-V1')/RUN_ID
subprocess.run(['python','-m','cegwm.baselines.external_canary','--method','shallow_diffuse','--run-dir',str(run_dir),'--project-exact',resolved_exact,'--official-source',str(official)],cwd=root,check=True)
assert (run_dir/'final_manifest.json').is_file(); print('engineering-only canary; Drive:',run_dir)
